# %% [markdown]
# # ABOUT DATASET
# This dataset is having the data of 1K+ Amazon Product's Ratings and Reviews as per their details listed on the official website of Amazon.
#
# **---Features---**
#
# **•	product_id -** Product ID
#
# **•	product_name -** Name of the Product
#
# **•	category -** Category of the Product
#
# **•	discounted_price -** Discounted Price of the Product
#
# **•	actual_price -** Actual Price of the Product
#
# **•	discount_percentage -** Percentage of Discount for the Product
#
# **•	rating -** Rating of the Product
#
# **•	rating_count -** Number of people who voted for the Amazon rating
#
# **•	about_product -** Description about the Product
#
# **•	user_id -** ID of the user who wrote review for the Product
#
# **•	user_name -** Name of the user who wrote review for the Product
#
# **•	review_id -** ID of the user review
#
# **•	review_title -** Short review
#
# **•	review_content -** Long review
#
# **•	img_link -** Image Link of the Product
#
# **•	product_link -** Official Website Link of the Product
#
# # Inspiration
#
# Amazon is an American Tech Multi-National Company whose business interests include E-commerce, where they buy and store the inventory, and take care of everything from shipping and pricing to customer service and returns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Shipun Meher\Desktop\DATA ANALYTS -Data Set\AMAZON\amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# **rating_count         1463 non-null   object**---It have 2 missing values

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df["discounted_price"].unique()
# Out:
# array(['₹399', '₹199', '₹329', '₹154', '₹149', '₹176.63', '₹229', '₹499',
#        '₹299', '₹219', '₹350', '₹159', '₹349', '₹13,999', '₹249',
#        '₹13,490', '₹970', '₹279', '₹59', '₹11,499', '₹14,999', '₹179',
#        '₹389', '₹599', '₹99', '₹899', '₹32,999', '₹209', '₹19,999',
#        '₹999', '₹333', '₹507', '₹309', '₹1,199', '₹799', '₹6,999', '₹230',
#        '₹649', '₹15,999', '₹348', '₹32,990', '₹139', '₹263', '₹7,999',
#        '₹1,599', '₹26,999', '₹115', '₹10,901', '₹1,434', '₹7,299', '₹325',
#        '₹29,999', '₹27,999', '₹30,990', '₹269', '₹24,999', '₹18,990',
#        '₹290', '₹345', '₹1,099', '₹719', '₹849', '₹21,999', '₹449',
#        '₹37,999', '₹7,390', '₹273.10', '₹15,990', '₹210', '₹1,299',
#        '₹347', '₹228', '₹1,499', '₹8,499', '₹20,990', '₹9,999', '₹489',
#        '₹23,999', '₹689', '₹1,699', '₹655', '₹749', '₹195', '₹416',
#        '₹368', '₹29,990', '₹339', '₹15,490', '₹9,490', '₹637', '₹1,089',
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df["actual_price"].unique()
# Out:
# array(['₹1,099', '₹349', '₹1,899', '₹699', '₹399', '₹1,000', '₹499',
#        '₹299', '₹999', '₹339', '₹799', '₹700', '₹899', '₹24,999',
#        '₹21,990', '₹1,799', '₹22,900', '₹199', '₹19,990', '₹19,999',
#        '₹1,999', '₹750', '₹599', '₹666.66', '₹1,900', '₹45,999', '₹695',
#        '₹34,999', '₹1,599', '₹1,208', '₹475', '₹395', '₹2,199', '₹500',
#        '₹2,100', '₹12,999', '₹1,399', '₹21,999', '₹1,499', '₹47,900',
#        '₹845', '₹1,400', '₹14,990', '₹2,999', '₹42,999', '₹30,990',
#        '₹3,999', '₹249', '₹19,125', '₹1,299', '₹39,999', '₹40,990',
#        '₹52,900', '₹800', '₹31,999', '₹1,809', '₹29,999', '₹65,000',
#        '₹20,000', '₹23,990', '₹15,999', '₹44,990', '₹44,999', '₹1,700',
#        '₹595', '₹27,990', '₹1,200', '₹34,990', '₹1,500', '₹49,990',
#        '₹931', '₹2,399', '₹1,339', '₹20,900', '₹15,990', '₹1,600', '₹849',
#        '₹1,199', '₹22,990', '₹2,499', '₹47,990', '₹485', '₹18,990',
# ...

# %%
df["discount_percentage"].unique()
# Out:
# array(['64%', '43%', '90%', '53%', '61%', '85%', '65%', '23%', '50%',
#        '33%', '55%', '63%', '69%', '60%', '13%', '44%', '38%', '39%',
#        '46%', '41%', '70%', '42%', '72%', '25%', '51%', '73%', '0%',
#        '80%', '28%', '67%', '58%', '35%', '45%', '62%', '54%', '27%',
#        '77%', '56%', '78%', '31%', '86%', '47%', '37%', '75%', '32%',
#        '68%', '66%', '22%', '57%', '17%', '52%', '88%', '20%', '59%',
#        '40%', '26%', '29%', '83%', '71%', '15%', '76%', '48%', '82%',
#        '36%', '89%', '87%', '24%', '34%', '11%', '91%', '7%', '19%',
#        '79%', '21%', '81%', '18%', '49%', '30%', '84%', '10%', '6%',
#        '14%', '74%', '4%', '5%', '16%', '8%', '2%', '94%', '12%', '3%',
#        '9%'], dtype=object)

# %%
df["rating"].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df["rating_count"].unique()
# Out:
# array(['24,269', '43,994', '7,928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
df=df.dropna()

# %%
df=df.drop(columns=['product_id','user_id', 'user_name', 'review_id', 'review_title','review_content', 'img_link', 'product_link','about_product'])

# %%
df
# Out:
#                                            product_name  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     Sounce Fast Phone Charging Cable & Data Sync U...
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                 ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1     Computers&Accessories|Accessories&Peripherals|...             ₹199
# ...

# %%
df["discounted_price"]=df["discounted_price"].str.replace("'","")
df["discounted_price"]=df["discounted_price"].str.replace("₹","")
df["discounted_price"]=df["discounted_price"].str.replace(",","")

# %%
df["discounted_price"]=df["discounted_price"].astype(float)

# %%
df["actual_price"]=df["actual_price"].str.replace("'","")
df["actual_price"]=df["actual_price"].str.replace("₹","")
df["actual_price"]=df["actual_price"].str.replace(",","")

# %%
df["actual_price"]=df["actual_price"].astype(float)

# %%
df["discount_percentage"]=df["discount_percentage"].str.replace("'","")
df["discount_percentage"]=df["discount_percentage"].str.replace("%","")

# %%
df["discount_percentage"]=df["discount_percentage"].astype(int)

# %%
df["rating"]=df["rating"].str.replace("'","")
df["rating"]=df["rating"].str.replace("|","")

# %%
df["rating"].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df[df["rating"]== '']
# Out:
#                                            product_name  \
# 1279  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage rating rating_count
# 1279        2499.0                   16                 992

# %%
df["rating_count"]=df["rating_count"].str.replace("'","")
df["rating_count"]=df["rating_count"].str.replace('"','')
df["rating_count"]=df["rating_count"].str.replace("...","")
df["rating_count"]=df["rating_count"].str.replace(",","")

# %%
df["rating_count"]=df["rating_count"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1463 non-null   object
#  1   category             1463 non-null   object
#  2   discounted_price     1463 non-null   float64
#  3   actual_price         1463 non-null   float64
#  4   discount_percentage  1463 non-null   int32
#  5   rating               1463 non-null   object
#  6   rating_count         1463 non-null   float64
# dtypes: float64(3), int32(1), object(3)
# memory usage: 85.7+ KB

# %%
df
# Out:
#                                            product_name  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     Sounce Fast Phone Charging Cable & Data Sync U...
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                 ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# 1     Computers&Accessories|Accessories&Peripherals|...             199.0
# ...

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage   rating_count
# count       1463.000000    1463.000000          1463.000000    1463.000000
# mean        3129.277122    5451.068544            47.650718   18295.541353
# std         6948.222850   10881.018448            21.622373   42753.864952
# min           39.000000      39.000000             0.000000       2.000000
# 25%          325.000000     800.000000            32.000000    1186.000000
# 50%          799.000000    1690.000000            50.000000    5179.000000
# 75%         1999.000000    4312.500000            63.000000   17336.500000
# max        77990.000000  139900.000000            94.000000  426973.000000

# %%
df["category"].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          231
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers                                               1
# ...

# %%
plt.figure(figsize=(30,15))
sns.histplot(data=df,x=df["category"],kde=True)
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.histplot(data=df,x=df["discounted_price"],kde=True,color="green")
# Out:
# <Axes: xlabel='discounted_price', ylabel='Count'>

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=df,x=df["actual_price"],kde=True,color="black")
# Out:
# <Axes: xlabel='actual_price', ylabel='Count'>

# %%
df["discount_percentage"].value_counts()
# Out:
# discount_percentage
# 50    56
# 60    56
# 0     49
# 80    36
# 55    36
#       ..
# 2      2
# 7      2
# 94     1
# 89     1
# 9      1
# Name: count, Length: 92, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.histplot(data=df,x=df["discount_percentage"],kde=True,color="blue")
# Out:
# <Axes: xlabel='discount_percentage', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
plt.pie(x=df["rating"].value_counts(),
        labels=df["rating"].value_counts().index.to_list(),autopct="%0.2f%%")
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.histplot(data=df,x=df["rating_count"],kde=True,color="green")
# Out:
# <Axes: xlabel='rating_count', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1463 non-null   object
#  1   category             1463 non-null   object
#  2   discounted_price     1463 non-null   float64
#  3   actual_price         1463 non-null   float64
#  4   discount_percentage  1463 non-null   int32
#  5   rating               1463 non-null   object
#  6   rating_count         1463 non-null   float64
# dtypes: float64(3), int32(1), object(3)
# memory usage: 85.7+ KB

# %% [markdown]
# # ANALYSIS

# %% [markdown]
#  **1-Average discount percentage across all products**

# %%
df["discount_percentage"].mean()
# Out:
# 47.65071770334928

# %% [markdown]
# **2-category offers the highest average discount**

# %%
avg_dis=df.groupby("category")["discounted_price"].mean()
high_dis=avg_dis.sort_values(ascending=False).head(5)
high_dis
# Out:
# category
# Home&Kitchen|Heating,Cooling&AirQuality|AirConditioners|Split-SystemAirConditioners                     42990.000000
# Computers&Accessories|Laptops|TraditionalLaptops                                                        37247.000000
# Computers&Accessories|Tablets                                                                           26999.000000
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                           24840.190476
# Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|Vacuums|RoboticVacuums    23449.500000
# Name: discounted_price, dtype: float64

# %%
high_dis.plot(kind="bar",color="skyblue")
plt.title('Top 5 Categories with Highest Average Discounted Price')
# Out:
# Text(0.5, 1.0, 'Top 5 Categories with Highest Average Discounted Price')

# %% [markdown]
# **Correlation between discount_percent vs rating**

# %%
plt.scatter(df['discount_percentage'], df['rating'])
plt.show()

# %%
df=df.drop(index=1279)

# %%
df["rating"]=df["rating"].astype(float)

# %% [markdown]
# **Which category has the highest average rating**

# %%
h_avg_rate=df.groupby("category")["rating"].mean()
h_avg_rate_t5=h_avg_rate.sort_values(ascending=False).head(5)
h_avg_rate_t5
# Out:
# category
# Computers&Accessories|Tablets                                               4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters    4.5
# Electronics|Cameras&Photography|Accessories|Film                            4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                          4.5
# Name: rating, dtype: float64

# %%
h_avg_rate_t5.plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='rating'>

# %% [markdown]
# **categories have the most rating_count**

# %%
hrc=df.groupby("category")["rating_count"].mean()
top_5=hrc.sort_values(ascending=False).head()
top_5
# Out:
# category
# Home&Kitchen|Kitchen&Dining|KitchenTools|ManualChoppers&Chippers|Choppers    270563.000000
# Computers&Accessories|NetworkingDevices|NetworkAdapters|BluetoothAdapters     95116.000000
# Electronics|Accessories|MemoryCards|MicroSD                                   85660.923077
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                  80864.211538
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables                79418.916667
# Name: rating_count, dtype: float64

# %%
top_5.plot(kind="bar",color="red")
plt.title("Top 5 categories have the most rating_count")
# Out:
# Text(0.5, 1.0, 'Top 5 categories have the most rating_count')

# %%
df.columns
# Out:
# Index(['product_name', 'category', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count'],
#       dtype='object')

# %% [markdown]
# **Product having more than rating 4.5**

# %%
most_rate=df[df["rating"]>4.5] 
more_than4point5=most_rate.drop(columns=['category', 'discounted_price', 'actual_price','discount_percentage','rating_count'])
more_than4point5
# Out:
#                                            product_name  rating
# 137   10k 8k 4k HDMI Cable, Certified 48Gbps 1ms Ult...     4.6
# 174   Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...     4.7
# 447   Spigen EZ Fit Tempered Glass Screen Protector ...     4.6
# 459   Spigen EZ Fit Tempered Glass Screen Protector ...     4.7
# 468   Spigen EZ Fit Tempered Glass Screen Protector ...     4.6
# 571   WeCool S5 Long Selfie Stick, with Large Reinfo...     4.6
# 775   Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0
# 820   Redgear MP35 Speed-Type Gaming Mousepad (Black...     4.6
# 853   Logitech Pebble M350 Wireless Mouse with Bluet...     4.6
# 886   Logitech M331 Silent Plus Wireless Mouse, 2.4G...     4.6
# 964   Logitech G402 Hyperion Fury USB Wired Gaming M...     4.6
# 976   Xiaomi Pad 5| Qualcomm Snapdragon 860| 120Hz R...     4.6
# 1007  WeCool S5 Long Selfie Stick, with Large Reinfo...     4.6
# ...

# %%
plt.figure(figsize=(20,20))
plt.barh(more_than4point5["product_name"],more_than4point5["rating"])
plt.title("Product having more than rating 4.5")
# Out:
# Text(0.5, 1.0, 'Product having more than rating 4.5')

# %% [markdown]
# **Product having less than 3 rating**

# %%
less_rate=df[df["rating"]<3] 
less_rate_below_3=less_rate.drop(columns=['category', 'discounted_price', 'actual_price','discount_percentage','rating_count'])
less_rate_below_3
# Out:
#                                            product_name  rating
# 545   SHREENOVA ID116 Plus Bluetooth Fitness Smart W...     2.8
# 1243  Personal Size Blender, Portable Blender, Batte...     2.3
# 1286  MR. BRAND Portable USB Juicer Electric USB Jui...     2.8
# 1309  Khaitan ORFin Fan heater for Home and kitchen-...     2.0
# 1356  Green Tales Heat Seal Mini Food Sealer-Impulse...     2.6
# 1449  IONIX Tap filter Multilayer | Activated Carbon...     2.9

# %%
plt.figure(figsize=(10,15))
plt.barh(less_rate_below_3["product_name"],less_rate_below_3["rating"])
plt.title("Product having less than 2 rating")
plt.show()

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1462.000000    1462.000000          1462.000000  1462.000000
# mean        3129.981826    5453.087743            47.672367     4.096717
# std         6950.548042   10884.467444            21.613905     0.289497
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1670.000000            50.000000     4.100000
# 75%         1999.000000    4321.250000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1462.000000
# mean    18307.376881
# std     42766.096572
# min         2.000000
# 25%      1191.500000
# 50%      5179.000000
# 75%     17342.250000
# max    426973.000000

# %%
high_price=df["actual_price"].sort_values(ascending=False)
high_price.value_counts().sort_values(ascending=False)
# Out:
# actual_price
# 999.0      118
# 499.0       71
# 1999.0      56
# 1499.0      37
# 399.0       34
#           ...
# 13049.0      1
# 13150.0      1
# 13750.0      1
# 13999.0      1
# 3193.0       1
# Name: count, Length: 449, dtype: int64

# %%
low_rate=(df["rating"].sort_values(ascending=True))
low_rate
# Out:
# 1309    2.0
# 1243    2.3
# 1356    2.6
# 1286    2.8
# 545     2.8
#        ...
# 1145    4.8
# 1201    4.8
# 1299    4.8
# 174     5.0
# 775     5.0
# Name: rating, Length: 1462, dtype: float64

# %% [markdown]
# **Product having  low price with high rating**

# %%
df[(df["actual_price"]<1500) & (df["rating"]> 4.5)]
# Out:
#                                            product_name  \
# 775   Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 820   Redgear MP35 Speed-Type Gaming Mousepad (Black...
# 1119  Lint Remover Woolen Clothes Lint Extractor Bat...
# 1127  Ikea 903.391.72 Polypropylene Plastic Solid Be...
# 1201  Oratech Coffee Frother electric, milk frother ...
# 1216  VRPRIME Lint Roller Lint Remover for Clothes, ...
# 1226  Zuvexa USB Rechargeable Electric Foam Maker - ...
#
#                                                category  discounted_price  \
# 775   Computers&Accessories|Accessories&Peripherals|...             499.0
# 820   Computers&Accessories|Accessories&Peripherals|...             299.0
# 1119  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...             319.0
# 1127  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             160.0
# 1201  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             279.0
# ...

# %% [markdown]
# **Product having high price but low rating**

# %%
df[(df["actual_price"]>4321) & (df["rating"]< 3.5)]
# Out:
#                                           product_name  \
# 82   SKYWALL 81.28 cm (32 inches) HD Ready Smart LE...
# 463  PTron Newly Launched Force X10 Bluetooth Calli...
# 492  PTron Newly Launched Force X10 Bluetooth Calli...
# 506  PTron Newly Launched Force X10 Bluetooth Calli...
#
#                                               category  discounted_price  \
# 82   Electronics|HomeTheater,TV&Video|Televisions|S...            7299.0
# 463        Electronics|WearableTechnology|SmartWatches            1299.0
# 492        Electronics|WearableTechnology|SmartWatches            1399.0
# 506        Electronics|WearableTechnology|SmartWatches            1299.0
#
#      actual_price  discount_percentage  rating  rating_count
# 82        19125.0                   62     3.4         902.0
# 463        5999.0                   78     3.3        4415.0
# 492        5999.0                   77     3.3        4415.0
# 506        5999.0                   78     3.3        4415.0

# %% [markdown]
# **Corelation between price and rating**

# %%
corr_mat=df[["actual_price","rating"]].corr()
corr_mat
# Out:
#               actual_price    rating
# actual_price      1.000000  0.122467
# rating            0.122467  1.000000

# %%
sns.heatmap(corr_mat, annot=True)
plt.title("Corelation between price and rating")
# Out:
# Text(0.5, 1.0, 'Corelation between price and rating')

# %% [markdown]
# **Conclusion:There is a weak positive correlation (0.12) between "actual_price" and "rating", so changes in the actual price do not strongly influence the rating**

# %%
df
# Out:
#                                            product_name  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     Sounce Fast Phone Charging Cable & Data Sync U...
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                 ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# 1     Computers&Accessories|Accessories&Peripherals|...             199.0
# ...

# %%
df.to_excel("Amazon-cleaned_dataset.xlsx")
